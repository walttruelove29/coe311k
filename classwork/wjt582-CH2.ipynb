# %%
def base2(x):
    binary = ''
    while(x>0):
        binary = binary + str(x%2)
        x = int(x//2)
    binaryfinal = binary[::-1]
    return int(binaryfinal)

# %%
base2(2025)
# Out:
# 11111101001
