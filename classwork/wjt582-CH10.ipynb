# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(0, 1.01, 0.01)
error = np.random.uniform(-1, 1, len(X))
m = 2
b = 2
Y = m*X+b+error

# %% [markdown]
# Least Square Fit:

# %%
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Calculated Slope: {m}, Calculated Intercept: {c}")
y1 = m*X+c
# Out:
# Calculated Slope: 2.0261350909260982, Calculated Intercept: 2.0918104811830123

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(X, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y1)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y1)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 0.3255
# R-squared: 0.5174

# %% [markdown]
# Polynomial Fit:

# %%
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)
# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [ 3.06588742 -4.59232941  3.85002948  1.94415707]

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)
# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 0.3220
# R-squared: 0.5226

# %% [markdown]
# Part B:

# %% [markdown]
# Increasing Degree by 1

# %%
degree = 4 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-23.97589033  51.01766808 -35.31743287  10.59924261   1.6218204 ]
# Mean Squared Error: 0.3079
# R-squared: 0.5435

# %%
degree = 5 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-64.4097657  137.04852392 -91.76804751  17.83672627   3.15431703
#    1.85273714]
# Mean Squared Error: 0.3014
# R-squared: 0.5532

# %%
degree = 6 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [  40.34627019 -185.44857627  274.33037608 -164.60040089   35.82653264
#     1.40755226    1.89021366]
# Mean Squared Error: 0.3012
# R-squared: 0.5534

# %%
degree = 7 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ -340.89673876  1233.48485587 -1834.91678102  1415.15442377
#   -575.94449861   108.58792437    -3.76770493     1.97035033]
# Mean Squared Error: 0.3004
# R-squared: 0.5545

# %%
degree = 8 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-1.05175290e+03  3.86611485e+03 -5.62903451e+03  4.02810078e+03
#  -1.38558020e+03  1.62009004e+02  1.02854439e+01  1.55901931e+00
#   1.90903433e+00]
# Mean Squared Error: 0.3000
# R-squared: 0.5552

# %%
degree = 9 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-1.72224478e+04  7.64492622e+04 -1.41857068e+05  1.42730703e+05
#  -8.45369945e+04  2.99635168e+04 -6.16788336e+03  6.68552240e+02
#  -2.64275326e+01  2.15354983e+00]
# Mean Squared Error: 0.2923
# R-squared: 0.5666

# %% [markdown]
# I would argue that right here is when the model becomes the most blatantly overfitted. There are several sharp turns in the model as it seeks to follow the points, and it appears that if one were to extend it beyond the data, it would likely go in very disparate directions.

# %% [markdown]
# Decreasing Degree by 1:

# %%
degree = 2 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [0.00650172 2.01963337 2.09288326]
# Mean Squared Error: 0.3255
# R-squared: 0.5174

# %%
degree = 1 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [2.02613509 2.09181048]
# Mean Squared Error: 0.3255
# R-squared: 0.5174

# %% [markdown]
# At this point, the polynomial fit is underfitted as it is just a straight line roughly following the data.
