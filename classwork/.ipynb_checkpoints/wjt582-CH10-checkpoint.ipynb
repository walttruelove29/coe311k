# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(0, 1.01, 0.01)
error = np.random.uniform(-2, 2, len(X))
Y = 2*X+2+error

# %% [markdown]
# Least Square Fit:

# %%
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Calculated Slope: {m}, Calculated Intercept: {c}")
y1 = m*X+c
# Out:
# Calculated Slope: 2.2289464117688174, Calculated Intercept: 1.8418099497718576

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(X, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y1)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y1)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 1.0868
# R-squared: 0.2798

# %% [markdown]
# Polynomial Fit:

# %%
degree = 3 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)
# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [ 2.09068315 -4.21445362  4.55555496  1.56245014]

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(X)
# Step 4: Plotting the results
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error: 8.1774
# R-squared: 0.0216

# %% [markdown]
# The Least Square Method provides a better fit for this data as it has a lower MSE and an R-squared closer to 1

# %% [markdown]
# Part B:

# %% [markdown]
# Increasing Degree by 1

# %%
degree = 4 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-15.71512433  33.52093182 -24.35338545   8.97936246   1.35117287]
# Mean Squared Error: 1.0723
# R-squared: 0.2894

# %%
degree = 5 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [  72.2470722  -196.33280483  193.6806497   -83.97528179   17.33017805
#     1.09215844]
# Mean Squared Error: 1.0641
# R-squared: 0.2948

# %%
degree = 5 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [  72.2470722  -196.33280483  193.6806497   -83.97528179   17.33017805
#     1.09215844]
# Mean Squared Error: 1.0641
# R-squared: 0.2948

# %%
degree = 6 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 151.4695182  -382.16148239  319.05600079  -79.74937055  -16.43725931
#    10.77240661    1.23285424]
# Mean Squared Error: 1.0618
# R-squared: 0.2964

# %%
degree = 7 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-1.74317473e+03  6.25258106e+03 -8.81671353e+03  6.15265727e+03
#  -2.18315651e+03  3.55627958e+02 -1.56912597e+01  1.64263290e+00]
# Mean Squared Error: 1.0423
# R-squared: 0.3093

# %%
degree = 8 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 3.21045291e+03 -1.45849864e+04  2.72002726e+04 -2.67134475e+04
#   1.47018390e+04 -4.43574358e+03  6.55694148e+02 -3.19509699e+01
#   1.82979866e+00]
# Mean Squared Error: 1.0381
# R-squared: 0.3121

# %%
degree = 9 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 4.27568112e+04 -1.89195197e+05  3.47190454e+05 -3.41120732e+05
#   1.93160121e+05 -6.31260887e+04  1.12789804e+04 -9.78532849e+02
#   3.75290326e+01  1.22275933e+00]
# Mean Squared Error: 0.9908
# R-squared: 0.3435

# %%
degree = 10 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-5.85892954e+04  3.35703288e+05 -8.13041680e+05  1.08489752e+06
#  -8.70510755e+05  4.29730651e+05 -1.28084585e+05  2.16770501e+04
#  -1.84599061e+03  6.71383601e+01  1.02356014e+00]
# Mean Squared Error: 0.9851
# R-squared: 0.3472

# %%
degree = 11 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-1.25178354e+05  6.29891653e+05 -1.30219289e+06  1.39388400e+06
#  -7.67201577e+05  1.32216223e+05  7.89637813e+04 -5.08963449e+04
#   1.16275521e+04 -1.15885846e+03  4.79560629e+01  1.12387943e+00]
# Mean Squared Error: 0.9835
# R-squared: 0.3483

# %%
degree = 12 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 1.24898234e+06 -7.61907241e+06  2.03280538e+07 -3.10989746e+07
#   3.00437994e+07 -1.90190077e+07  7.92200412e+06 -2.12272710e+06
#   3.47030907e+05 -3.13698382e+04  1.29309314e+03 -8.89385141e+00
#   1.35627344e+00]
# Mean Squared Error: 0.9734
# R-squared: 0.3550

# %%
degree = 13 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-4.87951626e+06  3.29658380e+07 -9.89070338e+07  1.73526429e+08
#  -1.97213118e+08  1.51897748e+08 -8.05592736e+07  2.92789797e+07
#  -7.11719000e+06  1.10286954e+06 -1.00274284e+05  4.61831076e+03
#  -7.37706051e+01  1.56400451e+00]
# Mean Squared Error: 0.9636
# R-squared: 0.3614

# %%
degree = 14 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 3.38474462e+07 -2.41811640e+08  7.74076362e+08 -1.46545256e+09
#   1.82362125e+09 -1.56790223e+09  9.52655659e+08 -4.11087368e+08
#   1.24740804e+08 -2.59359741e+07  3.52517694e+06 -2.89154633e+05
#   1.24287992e+04 -2.03484087e+02  1.88902038e+00]
# Mean Squared Error: 0.9343
# R-squared: 0.3809

# %%
degree = 15 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-1.53415405e+08  1.18446298e+09 -4.12828410e+09  8.58514504e+09
#  -1.18618653e+10  1.14743407e+10 -7.97674135e+09  4.02565801e+09
#  -1.47169744e+09  3.84338976e+08 -6.97320216e+07  8.38301277e+06
#  -6.16970534e+05  2.41716595e+04 -3.71211905e+02  2.21667252e+00]
# Mean Squared Error: 0.8966
# R-squared: 0.4058

# %%
degree = 16 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 8.49096702e+08 -6.94618883e+09  2.58257407e+10 -5.77436954e+10
#   8.65805734e+10 -9.19052714e+10  7.10675926e+10 -4.05736056e+10
#   1.71458181e+10 -5.32595416e+09  1.19564294e+09 -1.88348059e+08
#   1.98475011e+07 -1.29337106e+06  4.53659521e+04 -6.34065512e+02
#   2.61443728e+00]
# Mean Squared Error: 0.8249
# R-squared: 0.4533

# %%
degree = 17 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [ 4.41524266e+08 -2.90385617e+09  7.60570113e+09 -8.25441368e+09
#  -3.94292668e+09  2.60789844e+10 -4.19680899e+10  4.03517066e+10
#  -2.64238383e+10  1.22807393e+10 -4.09191660e+09  9.69514137e+08
#  -1.59389456e+08  1.73849435e+07 -1.16519021e+06  4.18216172e+04
#  -5.95553074e+02  2.56970141e+00]
# Mean Squared Error: 0.8237
# R-squared: 0.4541

# %%
degree = 18 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-6.43762565e+09  5.83803869e+10 -2.42040180e+11  6.07412552e+11
#  -1.02958435e+12  1.24524799e+12 -1.10647227e+12  7.32341767e+11
#  -3.61890204e+11  1.32352323e+11 -3.50153436e+10  6.39060443e+09
#  -7.20033274e+08  3.18943532e+07  2.95046148e+06 -4.96873492e+05
#   2.53792387e+04 -4.37609283e+02  2.42999375e+00]
# Mean Squared Error: 0.8079
# R-squared: 0.4646

# %%
degree = 19 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-4.11663707e+09  3.30359471e+10 -1.16112500e+11  2.29509977e+11
#  -2.63614594e+11  1.35256789e+11  7.98981957e+10 -2.17742591e+11
#   2.10671904e+11 -1.25561905e+11  4.99942148e+10 -1.31393430e+10
#   2.03131555e+09 -8.38896996e+07 -3.37046392e+07  7.48268374e+06
#  -6.89860946e+05  2.97611114e+04 -4.76453662e+02  2.45879018e+00]
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3326: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Mean Squared Error: 0.8093
# R-squared: 0.4637

# %% [markdown]
# I would argue that right here is when the model becomes the most blatantly overfitted. There are several sharp turns in the function as it seeks to follow the points, and python even gave a warning that polyfit may be poorly conditioned.

# %% [markdown]
# Decreasing Degree by 1:

# %%
degree = 2 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [-1.07842889  3.3073753   1.66386918]
# Mean Squared Error: 1.0800
# R-squared: 0.2843

# %%
degree = 1 
coefficients = np.polyfit(X, Y, degree)

print("Polynomial Coefficients: ", coefficients)

polynomial = np.poly1d(coefficients)

y_pred = polynomial(X)

plt.scatter(X, Y, color='blue', label='Data points') 
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')

plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# Mean Squared Error (MSE)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
# R-squared value
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Polynomial Coefficients:  [2.22894641 1.84180995]
# Mean Squared Error: 1.0868
# R-squared: 0.2798

# %% [markdown]
# At this point, the polynomial fit is underfitted as it is just a straight line roughly following the data.
