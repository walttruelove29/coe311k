# %%
import numpy as np
import time as tm
import matplotlib.pyplot as plt

# %%
def naive_matrix_multiplication(A, B):
    n = len(A)
    C = [[0] * n for _ in range(n)]
    
    for i in range(n):
        for j in range(n):
            for k in range(n):
                C[i][j] += A[i][k] * B[k][j]
    return C

# %% [markdown]
# When comparing these two functions, I expect that the optimized function will consistently be much quicker than the naive one. As for the graphs themselves, I believe that both will exhibit a somewhat similar relationship between time and the size of the matrix, but I believe they will be on different scales.

# %%
rng = np.random.default_rng()
n = 3
naivetime = np.zeros(8)
opttime = np.zeros(8)
size = np.zeros(8)
for i in range(8):
    A = rng.uniform(low=1.0, high=10.1, size=(n, n))
    B = rng.uniform(low=1.0, high=10.1, size=(n, n))
    start1 = tm.time()
    C1 = naive_matrix_multiplication(A, B)
    end1 = tm.time()
    time1 = end1 - start1
    start2 = tm.time()
    C2 = A@B
    end2 = tm.time()
    time2 = end2 - start2
    naivetime[i] = time1
    opttime[i] = time2
    size[i] = n
    print(f"Size: {n}x{n}")
    print("Naive Function:")
    
    print(f"Time: {time1}")
    print("Optimized Function:")
    
    print(f"Time: {time2}")
    
    n = n*2
# Out:
# Size: 3x3
# Naive Function:
# Time: 0.020088672637939453
# Optimized Function:
# Time: 5.507469177246094e-05
# Size: 6x6
# Naive Function:
# Time: 0.0004918575286865234
# Optimized Function:
# Time: 1.6450881958007812e-05
# Size: 12x12
# Naive Function:
# Time: 0.0036804676055908203
# Optimized Function:
# Time: 3.218650817871094e-05
# Size: 24x24
# Naive Function:
# Time: 0.029056310653686523
# Optimized Function:
# Time: 3.409385681152344e-05
# Size: 48x48
# Naive Function:
# Time: 0.1088099479675293
# Optimized Function:
# Time: 7.653236389160156e-05
# Size: 96x96
# Naive Function:
# Time: 0.8739845752716064
# Optimized Function:
# Time: 0.0002617835998535156
# Size: 192x192
# Naive Function:
# Time: 6.920276165008545
# Optimized Function:
# Time: 0.0005342960357666016
# Size: 384x384
# Naive Function:
# Time: 58.06435251235962
# Optimized Function:
# Time: 0.0031805038452148438

# %%
print(naivetime)
print(opttime)
print(size)
# Out:
# [2.00886726e-02 4.91857529e-04 3.68046761e-03 2.90563107e-02
#  1.08809948e-01 8.73984575e-01 6.92027617e+00 5.80643525e+01]
# [5.50746918e-05 1.64508820e-05 3.21865082e-05 3.40938568e-05
#  7.65323639e-05 2.61783600e-04 5.34296036e-04 3.18050385e-03]
# [  3.   6.  12.  24.  48.  96. 192. 384.]

# %%
plt.figure()
plt.plot(size, naivetime)
plt.xlabel('NxN size of the Multiplied Matrices')
plt.ylabel('Runtime')
plt.title('Naive Multiplication Matrix Number vs Runtime')
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(size, opttime)
plt.xlabel('NxN size of the Multiplied Matrices')
plt.ylabel('Runtime')
plt.title('Optimized Multiplication Matrix Number vs Runtime')
plt.grid()
plt.show()

# %% [markdown]
# Both graphs ultimately exhibited a similar relationship between matrix number and runtime for both functions, and runtime for the optimized function was consistently faster than the naive one.
