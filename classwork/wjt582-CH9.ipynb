# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # NOT YET COMPLETE

# %% [markdown]
# Part 1 Least Square Fit with Given Values:

# %%
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

print("X:")
print(X)

print("Y:")
print(Y)

print("A:")
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Y:
# [1.2 2.8 3.6 4.5 5.1]
# A:
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
x1 = np.linspace(min(X), max(X), 100)
y1 = 0.95*x1+0.59

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(x1, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()

# %% [markdown]
# Part 2 Least Square Fit with Random Values:

# %%
X = np.random.rand(5)
Y = np.random.rand(5)
A = np.vstack([X, np.ones(len(X))]).T

print("X:")
print(X)

print("Y:")
print(Y)

print("A:")
print(A)
# Out:
# X:
# [0.38038695 0.57388186 0.5538538  0.67083306 0.64769227]
# Y:
# [0.76611395 0.82115462 0.56675159 0.83252972 0.41598159]
# A:
# [[0.38038695 1.        ]
#  [0.57388186 1.        ]
#  [0.5538538  1.        ]
#  [0.67083306 1.        ]
#  [0.64769227 1.        ]]

# %%
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: -0.36450712338304225, Intercept: 0.8865729540634572

# %%
x1 = np.linspace(min(X), max(X), 100)
y1 = m*x1+c

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(x1, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()
