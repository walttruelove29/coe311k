# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Part 1 Least Square Fit with Given Values:

# %%
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

print("X:")
print(X)

print("Y:")
print(Y)

print("A:")
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Y:
# [1.2 2.8 3.6 4.5 5.1]
# A:
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
x1 = np.linspace(min(X), max(X), 100)
y1 = 0.95*x1+0.59

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(x1, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()

# %% [markdown]
# Part 2 Least Square Fit with Random Values:

# %%
X = np.random.rand(5)
Y = np.random.rand(5)
A = np.vstack([X, np.ones(len(X))]).T

print("X:")
print(X)

print("Y:")
print(Y)

print("A:")
print(A)
# Out:
# X:
# [0.26873848 0.9922695  0.3307568  0.06162056 0.15300282]
# Y:
# [0.97757248 0.10058938 0.5202916  0.13410914 0.05595987]
# A:
# [[0.26873848 1.        ]
#  [0.9922695  1.        ]
#  [0.3307568  1.        ]
#  [0.06162056 1.        ]
#  [0.15300282 1.        ]]

# %%
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: -0.17513114953054965, Intercept: 0.4209754630619362

# %%
x1 = np.linspace(min(X), max(X), 100)
x1 = np.sort(x1)
y1 = m*x1+c

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(x1, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()

# %% [markdown]
# Part 3: Least Square Fit with Generated Data

# %%
X = np.arange(0, 1.01, 0.01)
error = np.random.uniform(-1, 1, len(X))
Y = 2*x+2+error
A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print("Original Equation: Y=2X+2")
print(f"Calculated Slope: {m}, Calculated Intercept: {c}")
y1 = m*X+c
# Out:
# Original Equation: Y=2X+2
# Calculated Slope: 1.8652715494548042, Calculated Intercept: 2.0153235665572726

# %% [markdown]
# Residual Error:

# %%
rerror = np.abs(Y-y1)
print(f"Residuals: \n{rerror}")
maxrerror = np.max(rerror)
minrerror = np.min(rerror)
maxx = X[np.argmax(rerror)]
minx = X[np.argmin(rerror)]
print(f"Highest Residual Error: \n {maxrerror} at X={maxx}")
print(f"Lowest Residual Error: \n {minrerror} at X={minx}")
# Out:
# Residuals:
# [0.69649057 0.77323333 0.62968164 0.20209075 0.32460482 0.65393361
#  0.30497123 0.42035782 0.57250039 0.27331434 0.68313054 0.06708634
#  0.89231703 0.95529481 0.290825   0.23593609 0.22143281 0.31326248
#  0.72841972 0.97184418 0.05505974 0.37997188 0.07915414 0.21256717
#  0.09631317 0.61684081 0.26735054 0.92324715 0.75775207 0.10763441
#  0.46494017 0.16448172 0.2000962  0.83982734 0.36832594 0.10680534
#  0.78066871 0.15925695 0.86313948 0.87971572 0.12548672 0.85964849
#  0.39074544 0.86060071 0.82963599 0.28648072 0.69273547 0.79585113
#  0.04852079 0.92857933 0.8741943  0.17776982 0.39442581 0.86613334
#  0.9115893  0.23613588 0.91877127 0.72441095 0.34740612 0.10673136
#  0.88303714 0.00718274 0.64969823 0.47451967 0.70448419 0.36112859
#  0.32016529 1.01842219 0.84893761 0.36245028 0.37341142 0.28597287
#  0.7750492  0.13340809 0.3536029  0.22037846 0.50762057 0.58439435
#  0.43888142 0.10495901 0.58007606 0.47663225 0.38004637 0.85630658
# ...

# %% [markdown]
# Plotting:

# %%
plt.figure()
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(X, Y, label='Data Points')
plt.plot(X, y1, label='Best Fit Line')
plt.grid(True)
plt.legend()
plt.title("Least Squares Fit")
plt.show()
