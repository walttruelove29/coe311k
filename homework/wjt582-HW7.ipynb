# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Euler method function
def euler_method(h, x_start=0, x_end=10*np.pi):
    num_steps = int((x_end - x_start) / h)
    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)
    y_values[0] = 1  # y(0) = 1

    for i in range(num_steps):
        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])

    return x_values, y_values

# Function representing dy/dx = -2y*cos(x)
def f(x, y):
    return -2 * y * np.cos(x)

# %%
# Plotting different values of h vs. each other
h_values = [0.01, 0.5, 0.15, 0.2, 0.25, 0.35, 0.4, 0.45, 0.55, 0.6, 0.65, 0.75, 0.8, 0.85, 0.95, 1.0]
plt.figure(figsize=(20,10))
for h in h_values:
    x_values, y_values = euler_method(h)
    plt.plot(x_values, y_values, label= f'Euler\'s Method (h={h})')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Euler\'s Method Approximations for dy/dx = -2y*cos(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Error Calculation
average_y = 0.0
for h in h_values:
    x_values, y_values = euler_method(h)
    average_y += np.average(y_values)
average_y = average_y/18
plt.figure(figsize=(20,10))
average_error = np.zeros(18)
for i in range(18):
    for h in h_values:
        x_values, y_values = euler_method(h)
        average_error[i] = np.abs(y_values-average_y)
    plt.plot(h, average_error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b123bfca9a03> in <module>
#      10     for h in h_values:
#      11         x_values, y_values = euler_method(h)
# ---> 12         average_error[i] = np.abs(y_values-average_y)
#      13     plt.plot(h, average_error)
#      14
#
# ValueError: setting an array element with a sequence.
